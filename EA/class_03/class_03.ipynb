# %%
install.packages("mvtnorm")
# Out:
# Installing package into 'C:/Users/david.fernandes/AppData/Local/R/win-library/4.5'
# (as 'lib' is unspecified)
# package 'mvtnorm' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\david.fernandes\AppData\Local\Temp\Rtmpye5ti9\downloaded_packages

# %%
library(mvtnorm)
mu <- c(0, 0)
Sigma <- matrix(c(1, 0.8, 0.8, 1), nrow = 2)
data1 <- rmvnorm(n = 1000, mean = mu, sigma = Sigma)
plot(data1, pch = 19, col = rgb(0, 0, 1, 0.3))
x <- seq(-4, 4, length = 100)
y <- seq(-4, 4, length = 100)
grid <- expand.grid(X = x, Y = y)
z <- matrix(dmvnorm(grid, mean = mu, sigma = Sigma), nrow = 100)
persp(x, y, z, col = "lightblue", zlab = "Density")
# Out:
# plot without title
# plot without title
